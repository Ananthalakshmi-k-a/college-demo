# %%
import pandas as pd

# %%
data = pd.read_csv('Bird Strikes data.xlsx - Bird Strikes.csv')

# %%
data.head()
# Out:
#    Record ID Aircraft: Type                Airport: Name Altitude bin  \
# 0     202152       Airplane                 LAGUARDIA NY    > 1000 ft
# 1     208159       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2     207601       Airplane            LAKEFRONT AIRPORT    < 1000 ft
# 3     215953       Airplane          SEATTLE-TACOMA INTL    < 1000 ft
# 4     219878       Airplane                 NORFOLK INTL    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0            B-737-400                Over 100
# 1                MD-80                Over 100
# 2                C-500                Over 100
# 3            B-737-400                Over 100
# 4         CL-RJ100/200                Over 100
#
#    Wildlife: Number Struck Actual Effect: Impact to flight     FlightDate  \
# 0                           859.0         Engine Shut Down  11/23/00 0:00
# 1                           424.0                      NaN   7/25/01 0:00
# 2                           261.0                      NaN   9/14/01 0:00
# 3                           806.0    Precautionary Landing    9/5/02 0:00
# 4                           942.0                      NaN   6/23/03 0:00
#
#   Effect: Indicated Damage  ... Remains of wildlife sent to Smithsonian  \
# 0            Caused damage  ...                                   False
# 1            Caused damage  ...                                   False
# 2                No damage  ...                                   False
# 3                No damage  ...                                   False
# 4                No damage  ...                                   False
#
#                                              Remarks Wildlife: Size  \
# 0  FLT 753. PILOT REPTD A HUNDRED BIRDS ON UNKN T...         Medium
# 1  102 CARCASSES FOUND. 1 LDG LIGHT ON NOSE GEAR ...          Small
# 2  FLEW UNDER A VERY LARGE FLOCK OF BIRDS OVER AP...          Small
# 3  NOTAM WARNING. 26 BIRDS HIT THE A/C, FORCING A...          Small
# 4                                      NO DMG REPTD.          Small
#
#   Conditions: Sky      Wildlife: Species Pilot warned of birds or wildlife?  \
# 0        No Cloud  Unknown bird - medium                                  N
# 1      Some Cloud            Rock pigeon                                  Y
# 2        No Cloud      European starling                                  N
# 3      Some Cloud      European starling                                  Y
# 4        No Cloud      European starling                                  N
#
#   Cost: Total $ Feet above ground Number of people injured Is Aircraft Large?
# 0        30,736             1,500                      0.0                Yes
# 1             0                 0                      0.0                 No
# 2             0                50                      0.0                 No
# 3             0                50                      0.0                Yes
# 4             0                50                      0.0                 No
#
# [5 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16178 entries, 0 to 16177
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Record ID                                16178 non-null  int64
#  1   Aircraft: Type                           16135 non-null  object
#  2   Airport: Name                            16135 non-null  object
#  3   Altitude bin                             16134 non-null  object
#  4   Aircraft: Make/Model                     16177 non-null  object
#  5   Wildlife: Number struck                  16134 non-null  object
#  6   Wildlife: Number Struck Actual           16177 non-null  float64
#  7   Effect: Impact to flight                 1590 non-null   object
#  8   FlightDate                               16134 non-null  object
#  9   Effect: Indicated Damage                 16177 non-null  object
#  10  Aircraft: Number of engines?             16030 non-null  object
#  11  Aircraft: Airline/Operator               16134 non-null  object
#  12  Origin State                             15919 non-null  object
#  13  When: Phase of flight                    16134 non-null  object
#  14  Conditions: Precipitation                1389 non-null   object
#  15  Remains of wildlife collected?           16177 non-null  object
#  16  Remains of wildlife sent to Smithsonian  16177 non-null  object
#  17  Remarks                                  12870 non-null  object
#  18  Wildlife: Size                           16134 non-null  object
#  19  Conditions: Sky                          16177 non-null  object
#  20  Wildlife: Species                        16177 non-null  object
#  21  Pilot warned of birds or wildlife?       16134 non-null  object
#  22  Cost: Total $                            16177 non-null  object
#  23  Feet above ground                        16134 non-null  object
#  24  Number of people injured                 16177 non-null  float64
#  25  Is Aircraft Large?                       16134 non-null  object
# dtypes: float64(2), int64(1), object(23)
# memory usage: 3.2+ MB

# %%
data['Cost: Total $'] = data['Cost: Total $'].str.replace(',', '')
data['Feet above ground'] = data['Feet above ground'].str.replace(',','')

# %%
data.isnull().any()
# Out:
# Record ID                                  False
# Aircraft: Type                              True
# Airport: Name                               True
# Altitude bin                                True
# Aircraft: Make/Model                        True
# Wildlife: Number struck                     True
# Wildlife: Number Struck Actual              True
# Effect: Impact to flight                    True
# FlightDate                                  True
# Effect: Indicated Damage                    True
# Aircraft: Number of engines?                True
# Aircraft: Airline/Operator                  True
# Origin State                                True
# When: Phase of flight                       True
# Conditions: Precipitation                   True
# Remains of wildlife collected?              True
# Remains of wildlife sent to Smithsonian     True
# Remarks                                     True
# Wildlife: Size                              True
# Conditions: Sky                             True
# Wildlife: Species                           True
# Pilot warned of birds or wildlife?          True
# Cost: Total $                               True
# Feet above ground                           True
# Number of people injured                    True
# Is Aircraft Large?                          True
# dtype: bool

# %%
data.fillna(0,inplace=True)

# %%
data.isnull().any()
# Out:
# Record ID                                  False
# Aircraft: Type                             False
# Airport: Name                              False
# Altitude bin                               False
# Aircraft: Make/Model                       False
# Wildlife: Number struck                    False
# Wildlife: Number Struck Actual             False
# Effect: Impact to flight                   False
# FlightDate                                 False
# Effect: Indicated Damage                   False
# Aircraft: Number of engines?               False
# Aircraft: Airline/Operator                 False
# Origin State                               False
# When: Phase of flight                      False
# Conditions: Precipitation                  False
# Remains of wildlife collected?             False
# Remains of wildlife sent to Smithsonian    False
# Remarks                                    False
# Wildlife: Size                             False
# Conditions: Sky                            False
# Wildlife: Species                          False
# Pilot warned of birds or wildlife?         False
# Cost: Total $                              False
# Feet above ground                          False
# Number of people injured                   False
# Is Aircraft Large?                         False
# dtype: bool

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def outliers(str,column):
  plt.figure(figsize=(8,6))
  sns.boxplot(y=data[column])
  plt.title(f'The Boxplot of {column} {str}')
  plt.show()

# %%
for column in data:
  if data[column].dtype == 'int64' or data[column].dtype == 'float64':

    print("Before Outlier")
    outliers('Before Outlier',column)

    q1 = data[column].quantile(0.25)
    q3 = data[column].quantile(0.75)
    iqr =q3 - q1

    lb =q1 - 1.5 * iqr
    ub = q3 + 1.5 * iqr

    data.loc[(data[column] < lb),column] = lb
    data.loc[(data[column] > ub,column)] = ub

    print("After Outlier")
    outliers('After Outlier',column)
# Out:
# Before Outlier
# <ipython-input-12-9a257eb21d5c>:14: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '172320.25' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[(data[column] < lb),column] = lb
# After Outlier
# Before Outlier
# After Outlier
# Before Outlier
# After Outlier

# %%
data
# Out:
#        Record ID Aircraft: Type                Airport: Name Altitude bin  \
# 0       202152.0       Airplane                 LAGUARDIA NY    > 1000 ft
# 1       208159.0       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2       207601.0       Airplane            LAKEFRONT AIRPORT    < 1000 ft
# 3       215953.0       Airplane          SEATTLE-TACOMA INTL    < 1000 ft
# 4       219878.0       Airplane                 NORFOLK INTL    < 1000 ft
# ...          ...            ...                          ...          ...
# 16173   253369.0       Airplane                MCCARREN INTL    > 1000 ft
# 16174   254376.0       Airplane             LOS ANGELES INTL    < 1000 ft
# 16175   252166.0       Airplane              SACRAMENTO INTL    > 1000 ft
# 16176   250967.0       Airplane          SALT LAKE CITY INTL    < 1000 ft
# 16177   253848.0       Airplane                      PHILADE            0
#
#       Aircraft: Make/Model Wildlife: Number struck  \
# 0                B-737-400                Over 100
# 1                    MD-80                Over 100
# 2                    C-500                Over 100
# 3                B-737-400                Over 100
# 4             CL-RJ100/200                Over 100
# ...                    ...                     ...
# 16173                A-318                       1
# 16174            B-737-800                       1
# 16175            B-737-700                       1
# 16176            B-737-700                       1
# 16177                    0                       0
#
#        Wildlife: Number Struck Actual Effect: Impact to flight     FlightDate  \
# 0                                 6.0         Engine Shut Down  11/23/00 0:00
# 1                                 6.0                        0   7/25/01 0:00
# 2                                 6.0                        0   9/14/01 0:00
# 3                                 6.0    Precautionary Landing    9/5/02 0:00
# 4                                 6.0                        0   6/23/03 0:00
# ...                               ...                      ...            ...
# 16173                             1.0                        0   4/13/08 0:00
# 16174                             1.0                        0   4/14/08 0:00
# 16175                             1.0                        0   4/14/08 0:00
# 16176                             1.0                        0   4/14/08 0:00
# 16177                             0.0                        0              0
#
#       Effect: Indicated Damage  ... Remains of wildlife sent to Smithsonian  \
# 0                Caused damage  ...                                   False
# 1                Caused damage  ...                                   False
# 2                    No damage  ...                                   False
# 3                    No damage  ...                                   False
# 4                    No damage  ...                                   False
# ...                        ...  ...                                     ...
# 16173                No damage  ...                                   False
# 16174                No damage  ...                                   False
# 16175                No damage  ...                                   False
# 16176                No damage  ...                                    True
# 16177                        0  ...                                       0
#
#                                                  Remarks Wildlife: Size  \
# 0      FLT 753. PILOT REPTD A HUNDRED BIRDS ON UNKN T...         Medium
# 1      102 CARCASSES FOUND. 1 LDG LIGHT ON NOSE GEAR ...          Small
# 2      FLEW UNDER A VERY LARGE FLOCK OF BIRDS OVER AP...          Small
# 3      NOTAM WARNING. 26 BIRDS HIT THE A/C, FORCING A...          Small
# 4                                          NO DMG REPTD.          Small
# ...                                                  ...            ...
# 16173                                                  0          Small
# 16174  PILOT SAW STRIKE DURING T/O RUN AT LAX BUT REP...         Medium
# 16175      # STRUCK NOT REPTD, ASSUME 1, SAME AS # SEEN.          Small
# 16176       ID BY SMITHSONIAN, FAA 2402. ARPT CASE 0448.         Medium
# 16177                                                  0              0
#
#       Conditions: Sky      Wildlife: Species  \
# 0            No Cloud  Unknown bird - medium
# 1          Some Cloud            Rock pigeon
# 2            No Cloud      European starling
# 3          Some Cloud      European starling
# 4            No Cloud      European starling
# ...               ...                    ...
# 16173        No Cloud   Unknown bird - small
# 16174        No Cloud  Unknown bird - medium
# 16175        No Cloud   Unknown bird - small
# 16176        Overcast          American coot
# 16177               0                      0
#
#       Pilot warned of birds or wildlife? Cost: Total $ Feet above ground  \
# 0                                      N         30736              1500
# 1                                      Y             0                 0
# 2                                      N             0                50
# 3                                      Y             0                50
# 4                                      N             0                50
# ...                                  ...           ...               ...
# 16173                                  N             0              8000
# 16174                                  Y             0                 0
# 16175                                  N             0              6000
# 16176                                  Y             0               300
# 16177                                  0             0                 0
#
#       Number of people injured Is Aircraft Large?
# 0                          0.0                Yes
# 1                          0.0                 No
# 2                          0.0                 No
# 3                          0.0                Yes
# 4                          0.0                 No
# ...                        ...                ...
# 16173                      0.0                 No
# 16174                      0.0                Yes
# 16175                      0.0                Yes
# 16176                      0.0                Yes
# 16177                      0.0                  0
#
# [16178 rows x 26 columns]

# %%
data['FlightDate'] = pd.to_datetime(data['FlightDate'])

data['Year'] = data['FlightDate'].dt.year
data['Month'] = data['FlightDate'].dt.month
data['Day'] = data['FlightDate'].dt.day
data['hour'] = data['FlightDate'].dt.hour
data['minute'] = data['FlightDate'].dt.minute
# Out:
# <ipython-input-14-10de64a22f9a>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['FlightDate'] = pd.to_datetime(data['FlightDate'])

# %%
data.drop('FlightDate',axis = 1)
# Out:
#        Record ID Aircraft: Type                Airport: Name Altitude bin  \
# 0       202152.0       Airplane                 LAGUARDIA NY    > 1000 ft
# 1       208159.0       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2       207601.0       Airplane            LAKEFRONT AIRPORT    < 1000 ft
# 3       215953.0       Airplane          SEATTLE-TACOMA INTL    < 1000 ft
# 4       219878.0       Airplane                 NORFOLK INTL    < 1000 ft
# ...          ...            ...                          ...          ...
# 16173   253369.0       Airplane                MCCARREN INTL    > 1000 ft
# 16174   254376.0       Airplane             LOS ANGELES INTL    < 1000 ft
# 16175   252166.0       Airplane              SACRAMENTO INTL    > 1000 ft
# 16176   250967.0       Airplane          SALT LAKE CITY INTL    < 1000 ft
# 16177   253848.0       Airplane                      PHILADE            0
#
#       Aircraft: Make/Model Wildlife: Number struck  \
# 0                B-737-400                Over 100
# 1                    MD-80                Over 100
# 2                    C-500                Over 100
# 3                B-737-400                Over 100
# 4             CL-RJ100/200                Over 100
# ...                    ...                     ...
# 16173                A-318                       1
# 16174            B-737-800                       1
# 16175            B-737-700                       1
# 16176            B-737-700                       1
# 16177                    0                       0
#
#        Wildlife: Number Struck Actual Effect: Impact to flight  \
# 0                                 6.0         Engine Shut Down
# 1                                 6.0                        0
# 2                                 6.0                        0
# 3                                 6.0    Precautionary Landing
# 4                                 6.0                        0
# ...                               ...                      ...
# 16173                             1.0                        0
# 16174                             1.0                        0
# 16175                             1.0                        0
# 16176                             1.0                        0
# 16177                             0.0                        0
#
#       Effect: Indicated Damage Aircraft: Number of engines?  ...  \
# 0                Caused damage                            2  ...
# 1                Caused damage                            2  ...
# 2                    No damage                            2  ...
# 3                    No damage                            2  ...
# 4                    No damage                            2  ...
# ...                        ...                          ...  ...
# 16173                No damage                            2  ...
# 16174                No damage                            2  ...
# 16175                No damage                            2  ...
# 16176                No damage                            2  ...
# 16177                        0                            0  ...
#
#       Pilot warned of birds or wildlife? Cost: Total $ Feet above ground  \
# 0                                      N         30736              1500
# 1                                      Y             0                 0
# 2                                      N             0                50
# 3                                      Y             0                50
# 4                                      N             0                50
# ...                                  ...           ...               ...
# 16173                                  N             0              8000
# 16174                                  Y             0                 0
# 16175                                  N             0              6000
# 16176                                  Y             0               300
# 16177                                  0             0                 0
#
#       Number of people injured Is Aircraft Large?  Year Month Day hour minute
# 0                          0.0                Yes  2000    11  23    0      0
# 1                          0.0                 No  2001     7  25    0      0
# 2                          0.0                 No  2001     9  14    0      0
# 3                          0.0                Yes  2002     9   5    0      0
# 4                          0.0                 No  2003     6  23    0      0
# ...                        ...                ...   ...   ...  ..  ...    ...
# 16173                      0.0                 No  2008     4  13    0      0
# 16174                      0.0                Yes  2008     4  14    0      0
# 16175                      0.0                Yes  2008     4  14    0      0
# 16176                      0.0                Yes  2008     4  14    0      0
# 16177                      0.0                  0  1970     1   1    0      0
#
# [16178 rows x 30 columns]

# %%
yearly_strikes = data['Year'].value_counts().sort_index()
plt.figure(figsize=(12, 6))
yearly_strikes.plot(kind='bar')
plt.title('Yearly Bird Strikes in the US')
plt.xlabel('Year')
plt.ylabel('Number of Strikes')
plt.show()

# %%
us_airline_data = data[data['Aircraft: Airline/Operator'] == 'AMERICAN AIRLINES']

top_us_airlines = us_airline_data['Aircraft: Airline/Operator'].value_counts().head(10).sort_values(ascending=False)

# %%
# Top 10 US Airlines with Bird Strikes
plt.figure(figsize=(10, 8))
top_us_airlines.plot(kind='bar')
plt.title('Top 10 US Airlines with Bird Strikes')
plt.xlabel('Airline')
plt.ylabel('Number of Strikes')
plt.xticks(rotation=0)
plt.show()

# %%
# Top 50 Airports with Bird Strikes
top_airports = data['Airport: Name'].value_counts().head(50).sort_values(ascending=False)
plt.figure(figsize=(16, 8))
sns.barplot(x=top_airports.index, y=top_airports.values)
plt.title('Top 50 Airports with Bird Strikes')
plt.xlabel('Airport')
plt.ylabel('Number of Strikes')
plt.xticks(rotation=90)
plt.show()

# %%
data['Cost: Total $']= data['Cost: Total $'].astype(float)

# %%
# Yearly Cost Incurred due to Bird Strikes
yearly_cost = data.groupby('Year')['Cost: Total $'].sum()
plt.figure(figsize=(12, 6))
sns.lineplot(x=yearly_cost.index, y=yearly_cost.values)
plt.title('Yearly Cost Incurred due to Bird Strikes')
plt.xlabel('Year')
plt.ylabel('Total Cost ($)')
plt.show()

# %%
# Hourly Distribution of Bird Strikes
daily_strikes = data['Day'].value_counts().sort_index()
plt.figure(figsize=(12, 6))
daily_strikes.plot(kind='bar')
plt.title('Daily Distribution of Bird Strikes')
plt.xlabel('Day')
plt.ylabel('Number of Strikes')
plt.show()

# %%
data['Feet above ground'].astype(float)
# Out:
# 0        1500.0
# 1           0.0
# 2          50.0
# 3          50.0
# 4          50.0
#           ...
# 16173    8000.0
# 16174       0.0
# 16175    6000.0
# 16176     300.0
# 16177       0.0
# Name: Feet above ground, Length: 16178, dtype: float64

# %%
data.head(100)
# Out:
#     Record ID Aircraft: Type                  Airport: Name Altitude bin  \
# 0    202152.0       Airplane                   LAGUARDIA NY    > 1000 ft
# 1    208159.0       Airplane    DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2    207601.0       Airplane              LAKEFRONT AIRPORT    < 1000 ft
# 3    215953.0       Airplane            SEATTLE-TACOMA INTL    < 1000 ft
# 4    219878.0       Airplane                   NORFOLK INTL    < 1000 ft
# ..        ...            ...                            ...          ...
# 95   202117.0       Airplane  PANAMA CITY - BAY COUNTY INTL    < 1000 ft
# 96   202204.0       Airplane  BIRMINGHAM-SHUTTLESWORTH INTL    < 1000 ft
# 97   205917.0       Airplane  PANAMA CITY - BAY COUNTY INTL    < 1000 ft
# 98   204602.0       Airplane                      SUVA FIJI    < 1000 ft
# 99   205350.0       Airplane                    OXNARD ARPT    < 1000 ft
#
#    Aircraft: Make/Model Wildlife: Number struck  \
# 0             B-737-400                Over 100
# 1                 MD-80                Over 100
# 2                 C-500                Over 100
# 3             B-737-400                Over 100
# 4          CL-RJ100/200                Over 100
# ..                  ...                     ...
# 95               ATR-72                 2 to 10
# 96            B-737-300                 2 to 10
# 97               ATR-72                 2 to 10
# 98                A-320                 2 to 10
# 99                C-172                 2 to 10
#
#     Wildlife: Number Struck Actual Effect: Impact to flight FlightDate  \
# 0                              6.0         Engine Shut Down 2000-11-23
# 1                              6.0                        0 2001-07-25
# 2                              6.0                        0 2001-09-14
# 3                              6.0    Precautionary Landing 2002-09-05
# 4                              6.0                        0 2003-06-23
# ..                             ...                      ...        ...
# 95                             6.0                        0 2000-07-11
# 96                             3.0                        0 2000-07-12
# 97                             6.0                        0 2000-07-15
# 98                             5.0                        0 2000-07-16
# 99                             4.0                        0 2000-07-17
#
#    Effect: Indicated Damage  ... Pilot warned of birds or wildlife?  \
# 0             Caused damage  ...                                  N
# 1             Caused damage  ...                                  Y
# 2                 No damage  ...                                  N
# 3                 No damage  ...                                  Y
# 4                 No damage  ...                                  N
# ..                      ...  ...                                ...
# 95                No damage  ...                                  Y
# 96                No damage  ...                                  Y
# 97                No damage  ...                                  Y
# 98                No damage  ...                                  N
# 99                No damage  ...                                  N
#
#    Cost: Total $ Feet above ground Number of people injured  \
# 0        30736.0              1500                      0.0
# 1            0.0                 0                      0.0
# 2            0.0                50                      0.0
# 3            0.0                50                      0.0
# 4            0.0                50                      0.0
# ..           ...               ...                      ...
# 95           0.0                 0                      0.0
# 96           0.0                 0                      0.0
# 97           0.0                 0                      0.0
# 98           0.0               100                      0.0
# 99           0.0               100                      0.0
#
#    Is Aircraft Large?  Year Month Day hour minute
# 0                 Yes  2000    11  23    0      0
# 1                  No  2001     7  25    0      0
# 2                  No  2001     9  14    0      0
# 3                 Yes  2002     9   5    0      0
# 4                  No  2003     6  23    0      0
# ..                ...   ...   ...  ..  ...    ...
# 95                 No  2000     7  11    0      0
# 96                Yes  2000     7  12    0      0
# 97                 No  2000     7  15    0      0
# 98                 No  2000     7  16    0      0
# 99                 No  2000     7  17    0      0
#
# [100 rows x 31 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16178 entries, 0 to 16177
# Data columns (total 31 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Record ID                                16178 non-null  float64
#  1   Aircraft: Type                           16178 non-null  object
#  2   Airport: Name                            16178 non-null  object
#  3   Altitude bin                             16178 non-null  object
#  4   Aircraft: Make/Model                     16178 non-null  object
#  5   Wildlife: Number struck                  16178 non-null  object
#  6   Wildlife: Number Struck Actual           16178 non-null  float64
#  7   Effect: Impact to flight                 16178 non-null  object
#  8   FlightDate                               16178 non-null  datetime64[ns]
#  9   Effect: Indicated Damage                 16178 non-null  object
#  10  Aircraft: Number of engines?             16178 non-null  object
#  11  Aircraft: Airline/Operator               16178 non-null  object
#  12  Origin State                             16178 non-null  object
#  13  When: Phase of flight                    16178 non-null  object
#  14  Conditions: Precipitation                16178 non-null  object
#  15  Remains of wildlife collected?           16178 non-null  object
#  16  Remains of wildlife sent to Smithsonian  16178 non-null  object
#  17  Remarks                                  16178 non-null  object
#  18  Wildlife: Size                           16178 non-null  object
#  19  Conditions: Sky                          16178 non-null  object
#  20  Wildlife: Species                        16178 non-null  object
#  21  Pilot warned of birds or wildlife?       16178 non-null  object
#  22  Cost: Total $                            16178 non-null  float64
#  23  Feet above ground                        16178 non-null  object
#  24  Number of people injured                 16178 non-null  float64
#  25  Is Aircraft Large?                       16178 non-null  object
#  26  Year                                     16178 non-null  int32
#  27  Month                                    16178 non-null  int32
#  28  Day                                      16178 non-null  int32
#  29  hour                                     16178 non-null  int32
#  30  minute                                   16178 non-null  int32
# dtypes: datetime64[ns](1), float64(4), int32(5), object(21)
# memory usage: 3.5+ MB

# %%
# Convert 'Feet above ground' to float and update the DataFrame
data['Feet above ground'] = data['Feet above ground'].astype(float)

# %%
# Count bird strikes by altitude
altitude_counts = data.groupby('Altitude bin')['Wildlife: Number Struck Actual'].sum()

# Plotting the pie chart
plt.figure(figsize=(10, 6))
plt.pie(altitude_counts, labels=altitude_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Bird Strikes by Altitude')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.show()

# %%
# Distribution of Altitude at Time of Strike
plt.figure(figsize=(10, 6))
sns.histplot(data['Feet above ground'], bins=20, kde=True)
plt.title('Altitude Distribution at Time of Bird Strike')
plt.xlabel('Altitude')
plt.ylabel('Frequency')
plt.show()

# %%
# Distribution of Flight Phase at Time of Strike
flight_phase_counts = data['When: Phase of flight'].value_counts()

plt.figure(figsize=(10, 6))
sns.countplot(x='When: Phase of flight', data=data, order= flight_phase_counts.index)
plt.title('Flight Phase Distribution at Time of Bird Strike')
plt.xlabel('Flight Phase')
plt.ylabel('Number of Strikes')
plt.xticks(rotation=45)
plt.show()

# %%
# Average Altitude in Different Flight Phases
avg_altitude_phase = data.groupby('When: Phase of flight')['Feet above ground'].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
sns.barplot(x=avg_altitude_phase.index, y=avg_altitude_phase.values)
plt.title('Average Altitude in Different Flight Phases')
plt.xlabel('Flight Phase')
plt.ylabel('Average Altitude')
plt.xticks(rotation=45)
plt.show()

# %%
# Count occurrences of each category in 'Effect: Impact to flight'
impact_counts = data['Effect: Impact to flight'].value_counts()

# Plotting
plt.figure(figsize=(12, 6))

# Subplot for 'Effect: Impact to flight'
plt.subplot(1, 2, 1)
impact_counts.plot(kind='bar', color='skyblue')
plt.title('Effect: Impact to Flight')
plt.xlabel('Effect')
plt.ylabel('Frequency')



plt.tight_layout()
plt.show()

# %%
# Count occurrences of each category in 'Effect'
effect_counts = data['Effect: Indicated Damage'].value_counts()

# Plotting
plt.figure(figsize=(12, 6))

# Subplot for 'Effect'
plt.subplot(1, 2, 2)
effect_counts.plot(kind='bar', color='green')
plt.title('Effect of Bird Strikes')
plt.xlabel('Effect')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Effect of Bird Strike at Different Altitudes
plt.figure(figsize=(10, 6))
sns.barplot(x='Effect: Indicated Damage', y='Feet above ground', data=data)
plt.title('Effect of Bird Strike at Different Altitudes')
plt.xlabel('Effect on Flight')
plt.ylabel('Altitude')
plt.show()
